# %%
import matplotlib.pyplot as plt

X, Y = [], []
for line in open('data1/IM_0003-01_inx.txt', 'r'):
  values = [float(s) for s in line.split()]
  X.append(values[0])
  Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
import matplotlib.pyplot as plt

X, Y = [], []
for line in open('data1/IM_0004-01_inx.txt', 'r'):
  values = [float(s) for s in line.split()]
  X.append(values[0])
  Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
import matplotlib.pyplot as plt

X, Y = [], []
for line in open('data1/IM_0005-01_inx.txt', 'r'):
  values = [float(s) for s in line.split()]
  X.append(values[0])
  Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
import matplotlib.pyplot as plt

X, Y = [], []
for line in open('data1/IM_0008-01_inx.txt', 'r'):
  values = [float(s) for s in line.split()]
  X.append(values[0])
  Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
import matplotlib.pyplot as plt

X, Y = [], []
for line in open('data1/IM_0013-01_inx.txt', 'r'):
  values = [float(s) for s in line.split()]
  X.append(values[0])
  Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
# importing numpy package
import numpy as np
# importing matplotlib package
import matplotlib.pyplot as plt
 
# Creating an empty canvas(figure)
fig = plt.figure()
 
# Using the gca function, we are defining
# the current axes as a 3D projection
ax = fig.gca(projection='3d')

# Labelling X-Axis
ax.set_xlabel('X-Axis')
 
# Labelling Y-Axis
ax.set_ylabel('Y-Axis')
 
# Labelling Z-Axis
ax.set_zlabel('Z-Axis')

X, Y = [], []
for line in open('data1/IM_0003-01_inx.txt', 'r'):
  values = [float(s) for s in line.split()]
  X.append(values[0])
  Y.append(values[1])

plt.plot(X, Y)
plt.show()

z = [0]*len(X)
 
# zdir='z' fixes all the points to zs=0 and
# (x,y) points are ploted in the x-y axis
# of the graph
ax.plot(X, Y, zs=0, zdir='z')
 
# # zdir='y' fixes all the points to zs=0 and
# # (x,y) points are ploted in the x-z axis of the
# # graph
# ax.plot(z, Y, zs=0, zdir='y')
 
# # zdir='z' fixes all the points to zs=0 and
# # (x,z) points are ploted in the x-y axis of
# # the  graph
# ax.plot(X, z, zs=0, zdir='z')

plt.show()
# Out:
# C:\Users\khand\AppData\Local\Temp/ipykernel_13796/1364630632.py:11: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
fig = plt.figure()
 
# Using the gca function, we are defining
# the current axes as a 3D projection
ax = fig.gca(projection='3d')

# Labelling X-Axis
ax.set_xlabel('X-Axis')
 
# Labelling Y-Axis
ax.set_ylabel('Y-Axis')
 
# Labelling Z-Axis
ax.set_zlabel('Z-Axis')

X1, Z = [], []
for line in open('data1/IM_0008-01_inx.txt', 'r'):
  values = [float(s) for s in line.split()]
  X1.append(values[0])
  Z.append(values[1])

plt.plot(X1, Z)
plt.show()

Y = [0]*len(X1)
 
# zdir='z' fixes all the points to zs=0 and
# (x,y) points are ploted in the x-y axis
# of the graph
ax.plot(Z,X1, zdir='y')
 
# # zdir='y' fixes all the points to zs=0 and
# # (x,y) points are ploted in the x-z axis of the
# # graph
# ax.plot(z, Y, zs=0, zdir='y')
 
# # zdir='z' fixes all the points to zs=0 and
# # (x,z) points are ploted in the x-y axis of
# # the  graph
# ax.plot(X, z, zs=0, zdir='z')

plt.show()
# Out:
# C:\Users\khand\AppData\Local\Temp/ipykernel_13796/1462178835.py:5: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
